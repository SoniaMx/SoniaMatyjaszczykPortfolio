# %% [markdown]
# Exploration Data Analysis and classification based on default of credit card clients dataset.
#
# More comments below :)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
from sklearn.metrics import ConfusionMatrixDisplay, roc_curve, auc
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import joblib

# %%
data = pd.read_excel('default_of_credit_card_clients.xls', skiprows=1)
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
data.rename(columns={'default payment next month': 'Default'}, inplace=True)
data.rename(columns={'PAY_0':'PAY_1'}, inplace=True)
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
print("Data overview:")
display(data.head())
print("\nDataset size:", data.shape)
print("\nData types:")
print(data.dtypes)
# Out:
# Data overview:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  Default
# ...

# %%
print("\nCases where the customer did not repay(1) or pay(0)")
print(data['Default'].value_counts())
# Out:
# Cases where the customer did not repay(1) or pay(0)
# Default
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
print("\nStatistics:")
data.describe()
# Out:
# Statistics:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
print("\nMissing values")
print(data.isnull().sum())
# Out:
# Missing values
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_1        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# Default      0
# dtype: int64

# %%
plt.title('Division by education')
ax2 = sns.countplot(x='EDUCATION', hue='Default', data=data)
ax2.set_xticklabels(['unknown','graduate school','university','high school','others','unknown','unkown'], rotation=90)
plt.show()

# %% [markdown]
# Conclusion: Most debtors have higher education, university and high school. Among them, clients with higher education are more likely than others to
# fail to repay installments.

# %%
plt.title("Division by sex")
ax3 = sns.countplot(x='SEX', hue='Default', data=data)
ax3.set_xticklabels(['Male', 'Female'])
plt.show()

# %% [markdown]
# Conclusion: Women more often than men fail to repay installments.

# %%
plt.title("Division by age - Default(Red) vs No Default(Green)")
nodefault = data[data['Default']==0]['AGE']
default = data[data['Default']==1]['AGE']
sns.distplot(nodefault, bins=100, color='green')
sns.distplot(default, bins=100, color='red')
plt.show()

# %% [markdown]
# Conclusion: up to 30 years of age the propability to fail to repay installments is higher, after 30 years of age this probability decreases.

# %%
plt.title("Division by loan amount - Default(Red) vs No Default(Green)")
nodefault1 = data[data['Default']==0]['LIMIT_BAL']
default1 = data[data['Default']==1]['LIMIT_BAL']
sns.distplot(nodefault1, bins=100, color='green')
sns.distplot(default1, bins=100, color='red')
plt.show()

# %% [markdown]
# Conclusion: The most exposed to fail the repayment are customers with lower amount, especially those with 50 000 loan amount.

# %%
X = data.drop(['Default'], axis=1)
y = data['Default']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

print("Train Dataset:", X_train.shape)
print("Test Dataset:", X_test.shape)
# Out:
# Train Dataset: (21000, 24)
# Test Dataset: (9000, 24)

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)

rf_model = RandomForestClassifier(n_estimators=1000, max_depth=3, min_samples_leaf=int(X_train.shape[0]*0.001))
rf_model.fit(X_train, y_train)

lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

ada_model = AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1), n_estimators=50)
ada_model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1))

# %%
models = {"Decision Tress": dt_model, "Random Forest": rf_model, "Logistic Regression": lr_model, "AdaBoostClassifier": ada_model}

plt.figure(figsize=(15,5))
for i, (name, model) in enumerate (models.items()):
    y_pred = model.predict(X_test)
    plt.subplot(1, 4, i+1)
    ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred)).plot(ax=plt.gca())
    plt.title(f'Confusion Matrix - {name}')

plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 6))
for name, model in models.items():
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label = f'{name} (AUC = {roc_auc:.2f})')

plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Roc Curve')
plt.legend()
plt.show()

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    print(f"Accuracy (accuracy): {accuracy_score(y_test, y_pred)}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

# %%
print("\nDecision Tree")
evaluate_model(dt_model, X_test, y_test)

print("\nRandom Forest")
evaluate_model(rf_model, X_test, y_test)

print("\nLogistic Regression")
evaluate_model(lr_model, X_test, y_test)

print("\nAdaBoost")
evaluate_model(ada_model, X_test, y_test)
# Out:
# Decision Tree
# Accuracy (accuracy): 0.7242222222222222
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      7040
#            1       0.38      0.41      0.39      1960
#
#     accuracy                           0.72      9000
#    macro avg       0.60      0.61      0.61      9000
# weighted avg       0.73      0.72      0.73      9000
#
# Confusion Matrix:
# [[5721 1319]
#  [1163  797]]
#
# Random Forest
# Accuracy (accuracy): 0.8081111111111111
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      7040
#            1       0.67      0.23      0.35      1960
#
#     accuracy                           0.81      9000
#    macro avg       0.75      0.60      0.62      9000
# weighted avg       0.79      0.81      0.77      9000
#
# Confusion Matrix:
# [[6816  224]
#  [1503  457]]
#
# Logistic Regression
# ...

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, n_jobs=-1, scoring='recall')
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
best_score = grid_search.best_score_
test_score = grid_search.best_estimator_.score(X_test, y_test)

best_params, best_score, test_score
# Out:
# ({'max_depth': 30,
#   'min_samples_leaf': 1,
#   'min_samples_split': 5,
#   'n_estimators': 200},
#  0.3804488322135381,
#  0.817)

# %%
y_pred_proba = grid_search.best_estimator_.predict_proba(X_test)[:, 1]
y_pred = grid_search.best_estimator_.predict(X_test)

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid()
plt.show()

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=grid_search.best_estimator_.classes_)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      7040
#            1       0.64      0.36      0.46      1960
#
#     accuracy                           0.82      9000
#    macro avg       0.74      0.65      0.68      9000
# weighted avg       0.80      0.82      0.80      9000

# %%
rf_model = RandomForestClassifier(random_state=42)
param_distributions = {
    'n_estimators': [100, 300, 500],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'class_weight': ['balanced', {0: 1, 1: 4}]
}

random_search = RandomizedSearchCV(
    estimator=rf_model, param_distributions=param_distributions, 
    n_iter=50, cv=5, n_jobs=-1, scoring=make_scorer(f1_score, pos_label=1), random_state=42, verbose=2
)
random_search.fit(X_train, y_train)

print("Best params:", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Best params: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 10, 'class_weight': 'balanced'}

# %%
best_rf_model = random_search.best_estimator_

y_pred_rf = best_rf_model.predict(X_test)
y_pred_proba_rf = best_rf_model.predict_proba(X_test)[:, 1]

ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_rf)).plot()
plt.title('Confusion Matrix - Random Forest')
plt.show()


print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))


fpr, tpr, _ = roc_curve(y_test, y_pred_proba_rf)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'Random Forest (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-AUC Random Forest')
plt.legend()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      7040
#            1       0.50      0.55      0.52      1960
#
#     accuracy                           0.78      9000
#    macro avg       0.68      0.70      0.69      9000
# weighted avg       0.79      0.78      0.79      9000

# %%
param_distributions = {
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'class_weight': ['balanced', {0: 1, 1: 4}]
}

dt_model = DecisionTreeClassifier(random_state=42)

random_search = RandomizedSearchCV(
    estimator=dt_model, param_distributions=param_distributions, 
    n_iter=50, cv=5, n_jobs=-1, scoring=make_scorer(f1_score, pos_label=1), 
    random_state=42, verbose=2
)
random_search.fit(X_train, y_train)

print("Best params:", random_search.best_params_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# Best params: {'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': 10, 'class_weight': 'balanced'}

# %%
best_dt_model = random_search.best_estimator_
y_pred_dt = best_dt_model.predict(X_test)
y_pred_proba = best_dt_model.predict_proba(X_test)[:, 1]

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

ConfusionMatrixDisplay.from_estimator(best_dt_model, X_test, y_test)
plt.title("Confusion Matrix")
plt.show()

fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      7040
#            1       0.64      0.36      0.46      1960
#
#     accuracy                           0.82      9000
#    macro avg       0.74      0.65      0.68      9000
# weighted avg       0.80      0.82      0.80      9000

# %%
param_distributions_ada = {
    'n_estimators': [50, 100, 200, 500],
    'learning_rate': [0.01, 0.1, 0.5, 1.0],
    'algorithm': ['SAMME', 'SAMME.R']
}

ada_model = AdaBoostClassifier(random_state=42)

random_search_ada = RandomizedSearchCV(
    estimator=ada_model, param_distributions=param_distributions_ada, 
    n_iter=20, cv=5, scoring='f1', n_jobs=-1, random_state=42
)
random_search_ada.fit(X_train, y_train)

print("Best params AdaBoost:", random_search_ada.best_params_)
# Out:
# Best params AdaBoost: {'n_estimators': 200, 'learning_rate': 0.5, 'algorithm': 'SAMME.R'}

# %%
y_pred_ada = random_search_ada.best_estimator_.predict(X_test)
y_pred_proba_ada = random_search_ada.best_estimator_.predict_proba(X_test)[:, 1]

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_ada)
plt.show()

print("\nClassification Report AdaBoost:")
print(classification_report(y_test, y_pred_ada))

plt.figure(figsize=(8, 6))
fpr_ada, tpr_ada, _ = roc_curve(y_test, y_pred_proba_ada)
roc_auc_ada = auc(fpr_ada, tpr_ada)
plt.plot(fpr_ada, tpr_ada, label=f'AdaBoost (AUC = {roc_auc_ada:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve AdaBoost')
plt.legend()
plt.show()
# Out:
# Classification Report AdaBoost:
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.89      7040
#            1       0.65      0.32      0.43      1960
#
#     accuracy                           0.82      9000
#    macro avg       0.74      0.64      0.66      9000
# weighted avg       0.80      0.82      0.79      9000

# %%
param_distributions_lr = {
    'penalty': ['l1', 'l2', 'elasticnet', 'none'],
    'C': [0.1, 1.0, 10.0, 100.0],
    'solver': ['liblinear', 'saga'],
    'class_weight': ['balanced', None]
}

lr_model = LogisticRegression(max_iter=1000)

random_search_lr = RandomizedSearchCV(
    estimator=lr_model, param_distributions=param_distributions_lr, 
    n_iter=20, cv=5, scoring='f1', n_jobs=-1, random_state=42
)
random_search_lr.fit(X_train, y_train)

print("Best params Logistic Regression:", random_search_lr.best_params_)
# Out:
# Best params Logistic Regression: {'solver': 'liblinear', 'penalty': 'l1', 'class_weight': 'balanced', 'C': 0.1}

# %%
y_pred_lr = random_search_lr.best_estimator_.predict(X_test)
y_pred_proba_lr = random_search_lr.best_estimator_.predict_proba(X_test)[:, 1]

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_lr)
plt.show()

print("\nClassification Report Logistic Regression:")
print(classification_report(y_test, y_pred_lr))

plt.figure(figsize=(8, 6))
fpr_lr, tpr_lr, _ = roc_curve(y_test, y_pred_proba_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)
plt.plot(fpr_lr, tpr_lr, label=f'Logistic Regression (AUC = {roc_auc_lr:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve Logistic Regression')
plt.legend()
plt.show()
# Out:
# Classification Report Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.87      0.71      0.78      7040
#            1       0.38      0.63      0.47      1960
#
#     accuracy                           0.69      9000
#    macro avg       0.63      0.67      0.63      9000
# weighted avg       0.77      0.69      0.71      9000

# %%
rf_report = classification_report(y_test, y_pred_rf, output_dict=True)
lr_report = classification_report(y_test, y_pred_lr, output_dict=True)
dt_report = classification_report(y_test, y_pred_dt, output_dict=True)
ada_report = classification_report(y_test, y_pred_ada, output_dict=True)

rf_df = pd.DataFrame(rf_report).transpose().assign(Model='Random Forest')
lr_df = pd.DataFrame(lr_report).transpose().assign(Model='Logistic Regression')
dt_df = pd.DataFrame(dt_report).transpose().assign(Model='Decision Tree')
ada_df = pd.DataFrame(ada_report).transpose().assign(Model='AdaBoost')

summary_df = pd.concat([rf_df, lr_df, dt_df, ada_df])
summary_df = summary_df.loc[['0', '1'], ['precision', 'recall', 'f1-score', 'Model']]

print("Results summary:")
print(summary_df)
# Out:
# Results summary:
#    precision    recall  f1-score                Model
# 0   0.870117  0.847869  0.858849        Random Forest
# 0   0.874232  0.706960  0.781748  Logistic Regression
# 0   0.866207  0.802841  0.833321        Decision Tree
# 0   0.834869  0.952273  0.889715             AdaBoost
# 1   0.499533  0.545408  0.521463        Random Forest
# 1   0.376172  0.634694  0.472375  Logistic Regression
# 1   0.439192  0.554592  0.490192        Decision Tree
# 1   0.653608  0.323469  0.432765             AdaBoost

# %% [markdown]
# Conclusion: i chose RandomForest, LogistcRegression, DecisionTree and AdaBoost for classification. From the beginning i had problems with class 1 classification, to improve results i applied RandomizedSearchCV with scoring=f1 and class_weight=balanced. This helped me to balance classes and achieve better results for class 1. When it comes to class 0 every classifier did a great job, but the best are RandomForest and AdaBoost. When it comes to class 1 the best f1 score has RandomForest. To sum up in my opinion in this case the best classifier is RandomForest
